# %%
pip install uproot
# Out:
# Collecting uproot
#   Downloading https://files.pythonhosted.org/packages/e8/32/67f77a6a7e474caae7e3b85fdc2a96d354b7e8b4c88fdf2b524b27a8f795/uproot-3.10.12-py2.py3-none-any.whl (112kB)
#      |████████████████████████████████| 122kB 2.9MB/s
# Requirement already satisfied: cachetools in /usr/local/lib/python3.6/dist-packages (from uproot) (3.1.1)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.6/dist-packages (from uproot) (1.17.4)
# Collecting uproot-methods>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/dc/c7/687a2764f61176fed7172c3ea51199b92490e08f37dac75d2f65c4c65d33/uproot_methods-0.7.1-py2.py3-none-any.whl
# Collecting awkward<1.0,>=0.12.0
#   Downloading https://files.pythonhosted.org/packages/95/fb/7fd8cbf6a695135ae52b53a5022760f08eaa082ef1df71abc58be4049b9c/awkward-0.12.17-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 8.7MB/s
# Installing collected packages: awkward, uproot-methods, uproot
# Successfully installed awkward-0.12.17 uproot-3.10.12 uproot-methods-0.7.1

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/dark_matter_7_12_19
# Out:
# /content/gdrive/My Drive/dark_matter_7_12_19

# %%
import uproot
import pandas
import numpy as np
import matplotlib.pyplot as plt

tree50 = uproot.open("dark_matter_runs_50kev.root")["dstree"]
tree100 = uproot.open("dark_matter_100kev_v1.root")["dstree"]
tree150 = uproot.open("dark_matter_runs_150kev.root")["dstree"]
