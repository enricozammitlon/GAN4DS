# %% [markdown]
# # S1 vs s2 Conditional GAN
#
# As mentioned before, s1 and s2 are important characteristics to correctly model. Therefore the following script will create a conditional GAN, using s1 for dark matter at 50KeV and 200KeV

# %%
pip install uproot
# Out:
# Requirement already satisfied: uproot in /usr/local/lib/python3.6/dist-packages (3.10.12)
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.6/dist-packages (from uproot) (1.17.4)
# Requirement already satisfied: uproot-methods>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from uproot) (0.7.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.6/dist-packages (from uproot) (3.1.1)
# Requirement already satisfied: awkward<1.0,>=0.12.0 in /usr/local/lib/python3.6/dist-packages (from uproot) (0.12.17)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/My\ Drive/dark_matter_7_12_19
# Out:
# /content/gdrive/My Drive/dark_matter_7_12_19

# %% [markdown]
# Here we will extract some root files, most will be used to train the GAN, then one will be used to 'validate' the GAN.
#
# Currently, we will use 50, 150, and 250 to train and 100 and 200 to validate.

# %%
import uproot
import pandas
import numpy as np
import matplotlib.pyplot as plt

tree50 = uproot.open("dark_matter_runs_50kev.root")["dstree"]
tree100 = uproot.open("dark_matter_100kev_v1.root")["dstree"]
tree150 = uproot.open("dark_matter_runs_150kev.root")["dstree"]

# %%
tree50.show()
# Out:
# ev                         (no streamer)              asdtype('>i4')
# pdg                        (no streamer)              asdtype('>i4')
# ene0                       (no streamer)              asdtype('>f4')
# s1ene                      (no streamer)              asdtype('>f4')
# s2ene                      (no streamer)              asdtype('>f4')
# veto_visene                (no streamer)              asdtype('>f4')
# mu_visene                  (no streamer)              asdtype('>f4')
# vetoene                    (no streamer)              asdtype('>f4')
# muene                      (no streamer)              asdtype('>f4')
# tpcene                     (no streamer)              asdtype('>f4')
# x                          (no streamer)              asdtype('>f4')
# y                          (no streamer)              asdtype('>f4')
# z                          (no streamer)              asdtype('>f4')
# ene                        (no streamer)              asdtype('>f4')
# r                          (no streamer)              asdtype('>f4')
# px                         (no streamer)              asdtype('>f4')
# py                         (no streamer)              asdtype('>f4')
# pz                         (no streamer)              asdtype('>f4')
# tdrift                     (no streamer)              asdtype('>f4')
# npe                        (no streamer)              asdtype('>i4')
# munpe                      (no streamer)              asdtype('>i4')
# vnpe                       (no streamer)              asdtype('>i4')
# nph                        (no streamer)              asdtype('>i4')
# s1npe                      (no streamer)              asdtype('>i4')
# s2npe                      (no streamer)              asdtype('>i4')
# s1                         (no streamer)              asdtype('>f4')
# s2                         (no streamer)              asdtype('>f4')
# s1_corr                    (no streamer)              asdtype('>f4')
# s1_tile                    (no streamer)              asdtype('>i4')
# ndaughters                 (no streamer)              asdtype('>i4')
# ndeposits                  (no streamer)              asdtype('>i4')
# ndepositsTPC               (no streamer)              asdtype('>i4')
# nusers                     (no streamer)              asdtype('>i4')
# nphc                       (no streamer)              asdtype('>i4')
# dau_id                     (no streamer)              asjagged(asdtype('>i4'))
# dau_pdg                    (no streamer)              asjagged(asdtype('>i4'))
# dau_pid                    (no streamer)              asjagged(asdtype('>i4'))
# dau_process                (no streamer)              asjagged(asdtype('>i4'))
# dau_time                   (no streamer)              asjagged(asdtype('>f8'))
# dau_ene                    (no streamer)              asjagged(asdtype('>f4'))
# dau_x                      (no streamer)              asjagged(asdtype('>f4'))
# dau_y                      (no streamer)              asjagged(asdtype('>f4'))
# dau_z                      (no streamer)              asjagged(asdtype('>f4'))
# dau_r                      (no streamer)              asjagged(asdtype('>f4'))
# dau_px                     (no streamer)              asjagged(asdtype('>f4'))
# dau_py                     (no streamer)              asjagged(asdtype('>f4'))
# dau_pz                     (no streamer)              asjagged(asdtype('>f4'))
# dep_id                     (no streamer)              asjagged(asdtype('>i4'))
# dep_pdg                    (no streamer)              asjagged(asdtype('>i4'))
# dep_mat                    (no streamer)              asjagged(asdtype('>i4'))
# dep_time                   (no streamer)              asjagged(asdtype('>f8'))
# dep_ene                    (no streamer)              asjagged(asdtype('>f4'))
# dep_qene                   (no streamer)              asjagged(asdtype('>f4'))
# dep_step                   (no streamer)              asjagged(asdtype('>f4'))
# dep_x                      (no streamer)              asjagged(asdtype('>f4'))
# dep_y                      (no streamer)              asjagged(asdtype('>f4'))
# dep_z                      (no streamer)              asjagged(asdtype('>f4'))
# dep_r                      (no streamer)              asjagged(asdtype('>f4'))
# mat_fraction               (no streamer)              asdtype("('>f4', (100,))")
# depVeto                    (no streamer)              asdtype('>f4')
# qdepVeto                   (no streamer)              asdtype('>f4')
# prompt_npeVeto             (no streamer)              asdtype('>i4')
# prompt_npeNoise            (no streamer)              asdtype('>i4')
# prompt_timeVeto            (no streamer)              asdtype('>f8')
# prompt_zVeto               (no streamer)              asdtype('>f8')
# prompt_rVeto               (no streamer)              asdtype('>f8')
# late_npeVeto               (no streamer)              asdtype('>i4')
# late_timeVeto              (no streamer)              asdtype('>f8')
# userint1                   (no streamer)              asjagged(asdtype('>i4'))
# userint2                   (no streamer)              asjagged(asdtype('>i4'))
# userfloat1                 (no streamer)              asjagged(asdtype('>f4'))
# userfloat2                 (no streamer)              asjagged(asdtype('>f4'))
# userdouble0                (no streamer)              asjagged(asdtype('>f8'))
# pe_time                    (no streamer)              asjagged(asdtype('>f8'))
# pe_pmt                     (no streamer)              asjagged(asdtype('>i4'))
# f180like                   (no streamer)              asdtype('>f4')
# f200like                   (no streamer)              asdtype('>f4')
# f220like                   (no streamer)              asdtype('>f4')
# f180like_noise             (no streamer)              asdtype('>f4')
# f200like_noise             (no streamer)              asdtype('>f4')
# f220like_noise             (no streamer)              asdtype('>f4')
# f180like_tile              (no streamer)              asdtype('>f4')
# f200like_tile              (no streamer)              asdtype('>f4')
# f220like_tile              (no streamer)              asdtype('>f4')
# nclus                      (no streamer)              asdtype('>i4')
# cl_ene                     (no streamer)              asjagged(asdtype('>f4'))
# cl_true_ene                (no streamer)              asjagged(asdtype('>f4'))
# cl_ndep                    (no streamer)              asjagged(asdtype('>i4'))
# cl_x                       (no streamer)              asjagged(asdtype('>f4'))
# cl_y                       (no streamer)              asjagged(asdtype('>f4'))
# cl_z                       (no streamer)              asjagged(asdtype('>f4'))
# cl_t                       (no streamer)              asjagged(asdtype('>f4'))
# cl_npe                     (no streamer)              asjagged(asdtype('>i4'))
# cl_nucl                    (no streamer)              asjagged(asdtype('>f4'))
# cl_elec                    (no streamer)              asjagged(asdtype('>f4'))
# pe_ch                      (no streamer)              asdtype("('>i4', (38,))")
# s1_max_frac                (no streamer)              asdtype('>f4')
# vpe_time                   (no streamer)              asjagged(asdtype('>f8'))
# vpe_pmt                    (no streamer)              asjagged(asdtype('>i4'))
# mupe_time                  (no streamer)              asjagged(asdtype('>f8'))
# mupe_pmt                   (no streamer)              asjagged(asdtype('>i4'))
# ph_wl                      (no streamer)              asjagged(asdtype('>f4'))
# ph_x                       (no streamer)              asjagged(asdtype('>f4'))
# ph_y                       (no streamer)              asjagged(asdtype('>f4'))
# ph_z                       (no streamer)              asjagged(asdtype('>f4'))
# ph_time                    (no streamer)              asjagged(asdtype('>f8'))

# %% [markdown]
# The Variable is input here to try to make the code reusable and as general as possible.

# %%
#VARIABLE
var1 = "s1_corr"
var2 = "s2"

# %%
div1 = 1
#div1 = 2000
div2 = 1
#div2 = 22000
rangemins1 = 0
rangemaxs1 = 2000
rangemins2 = 2000
rangemaxs2 = 22000
train_DS_s1ene_50 = np.array(tree50.array(f"{var1}"))/div1
train_DS_s1ene_100 = np.array(tree100.array(f"{var1}"))/div1
train_DS_s1ene_150 = np.array(tree150.array(f"{var1}"))/div1

train_DS_s2ene_50 = np.array(tree50.array(f"{var2}"))/div2
train_DS_s2ene_100 = np.array(tree100.array(f"{var2}"))/div2
train_DS_s2ene_150 = np.array(tree150.array(f"{var2}"))/div2


fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(20)
ax1.hist(train_DS_s1ene_50,range = (rangemins1,rangemaxs1), density = True, bins = 205, alpha = 0.8, label = "50KeV")
ax1.hist(train_DS_s1ene_100,range = (rangemins1,rangemaxs1), density = True, bins = 205, alpha = 0.8, label = "100KeV")
ax1.hist(train_DS_s1ene_150,range = (rangemins1,rangemaxs1), density = True, bins = 205, alpha = 0.8, label = "150KeV")

ax1.set_xlabel("s1 Energy")
ax1.set_ylabel(r"$\rho\left(x\right)$", size=14, labelpad=30, rotation="horizontal")
ax1.legend(loc="upper right", fontsize=10)
#ax2.hist(train_DS_s2ene_150, density = True, bins = 10)
ax2.hist(train_DS_s2ene_50, range = (rangemins2,rangemaxs2),density = True, bins = 205, alpha = 0.8, label = "50KeV")
ax2.hist(train_DS_s2ene_100,range = (rangemins2,rangemaxs2), density = True, bins = 205, alpha = 0.8, label = "100KeV")
ax2.hist(train_DS_s2ene_150,range = (rangemins2,rangemaxs2), density = True, bins = 205, alpha = 0.8, label = "150KeV")

#ax2.set_ylim(top = 5)
ax2.set_xlabel("s2 Energy")
ax2.set_ylabel(r"$\rho\left(x\right)$", size=14, labelpad=30, rotation="horizontal")
#ax2.legend(loc="upper right", fontsize=10)
#print(np.mean(train_DS_s2ene_50))
plt.show()

# %%
num_train = int(1e3)
noise_size = 1000

# Length needs to be followed through
train_var = [50.,100., 150.]

# %%
from keras.layers     import BatchNormalization, Dense, Dropout, Input, LeakyReLU, Concatenate
from keras.models     import Model, Sequential
from keras.optimizers import Adam, SGD

import keras.backend as K
d_do = 0.2
g_nodes = 100
d_nodes = 100
g_do = 0.2
#Input of GEN VALUE
d1_in = Input((2,))
d1 = Dense(d_nodes, activation="relu")(d1_in)
d1 = Dropout(d_do)(d1)

#Input of parameter = energy
hyper_in = Input((1,))
d2 = Dense(d_nodes, activation="relu")(hyper_in)
d2 = Dropout(d_do)(d2)

dc = Concatenate()([d1, d2])
dc = Dense(g_nodes , activation="relu")(dc)
dc = Dropout(d_do)(dc)
dc = Dense(g_nodes , activation="relu")(dc)
dc = Dropout(d_do)(dc)
dc = Dense(g_nodes , activation="relu")(dc)
dc = Dropout(d_do)(dc)
dc = Dense(g_nodes , activation="relu")(dc)
dc = Dropout(d_do)(dc)
dc = Dense(g_nodes , activation="relu")(dc)
dc = LeakyReLU(0.2)(dc)
dc = Dropout(d_do)(dc)
dc = Dense(g_nodes , activation="relu")(dc)
dc = LeakyReLU(0.2)(dc)
dc = Dropout(d_do)(dc)
dc = Dense(2, activation="softmax")(dc)

dc = Model(name="Discriminator", inputs=[d1_in, hyper_in], outputs=[dc])
dc.compile(loss="categorical_crossentropy", optimizer=Adam(0.00025, beta_1=0.9), metrics=["accuracy"])
# 0.0005, beta_1=0.5
dc.summary()

#INPUT OF NOISE TO GENERATOR
g1_in = Input((noise_size,))
g1 = Dense(g_nodes, activation="relu")(g1_in)
g1 = Dropout(g_do)(g1)
g1 = BatchNormalization()(g1)
g1 = Dense(g_nodes, activation="relu")(g1)

#INPUT OF HYPERPARAM
g2 = Dense(g_nodes, activation="relu")(hyper_in)

gc = Concatenate()([g1, g2])
gc = BatchNormalization()(gc)
gc = Dropout(g_do)(gc)
gc = Dense(g_nodes, activation="relu")(gc)
gc = Dropout(g_do)(gc)
gc = Dense(g_nodes, activation="relu")(gc)
gc = Dropout(g_do)(gc)
gc = Dense(g_nodes, activation="relu")(gc)
gc = Dropout(g_do)(gc)
g1 = Dense(g_nodes, activation="relu")(g1)
gc = Dense(2, activation="linear")(gc)

gc = Model(name="Generator", inputs=[g1_in, hyper_in], outputs=[gc])
gc.summary()


gan_out = dc([gc([g1_in, hyper_in]), hyper_in])
gan = Model([g1_in, hyper_in], gan_out, name="GAN")
dc.trainable = False
#beta = 0.3, 0.0005
gan.compile(loss="categorical_crossentropy", optimizer=Adam(0.00025, beta_1=0.9), metrics=["accuracy"])
gan.summary()
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 100)          300         input_7[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 100)          200         input_8[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 100)          0           dense_35[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 100)          0           dense_36[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 200)          0           dropout_27[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 100)          20100       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 100)          0           dense_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 100)          10100       dropout_29[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 100)          0           dense_38[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 100)          10100       dropout_30[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 100)          0           dense_39[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 100)          10100       dropout_31[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 100)          0           dense_40[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 100)          10100       dropout_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 100)          0           dense_41[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 100)          0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 100)          10100       dropout_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 100)          0           dense_42[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 100)          0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 2)            202         dropout_34[0][0]
# ==================================================================================================
# Total params: 71,302
# Trainable params: 71,302
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "Generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 1000)         0
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 100)          100100      input_9[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 100)          0           dense_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100)          400         dropout_35[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 100)          10100       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 100)          200         input_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 200)          0           dense_45[0][0]
#                                                                  dense_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200)          800         concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 200)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 100)          20100       dropout_36[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 100)          0           dense_47[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 100)          10100       dropout_37[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 100)          0           dense_48[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 100)          10100       dropout_38[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 100)          0           dense_49[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 2)            202         dropout_39[0][0]
# ==================================================================================================
# Total params: 152,102
# Trainable params: 151,502
# Non-trainable params: 600
# __________________________________________________________________________________________________
# Model: "GAN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 1000)         0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# Generator (Model)               (None, 2)            152102      input_9[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# Discriminator (Model)           (None, 2)            71302       Generator[1][0]
#                                                                  input_8[0][0]
# ==================================================================================================
# Total params: 223,404
# Trainable params: 151,502
# Non-trainable params: 71,902
# __________________________________________________________________________________________________

# %%
#  Train GAN
rel_batch_size = 1
max_D_itrs_per_G_itr_e80 = 2
max_D_itrs_per_G_itr_e52 = 3

# %%
def plot_points_GAN (gen_data, train_DS_s1ene_50, train_DS_s1ene_100,train_DS_s1ene_150, epoch, batch_size, d_acc) :

    s1 = np.asarray(gen_DS)[:,0]
    s2 = np.asarray(gen_DS)[:,1]

    gen_class_length = int(gen_DS.shape[0]/3)
    gen_data_50_s1 = s1[:gen_class_length                    ]
    gen_data_100_s1 = s1[gen_class_length  :2*gen_class_length]
    gen_data_150_s1 = s1[2*gen_class_length:3*gen_class_length]


    gen_data_50_s2 = s2[:gen_class_length                    ]
    gen_data_100_s2 = s2[gen_class_length  :2*gen_class_length]
    gen_data_150_s2 = s2[2*gen_class_length:3*gen_class_length]


    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_figheight(5)
    fig.set_figwidth(20)
    fig.suptitle(f"s1 and s2 from a 2D cGAN at Epoch {epoch} and batch size {batch_size}")
    #y_max, x, _ = plt.hist(train_DS_s1ene_50,range = (0,70), density = True, bins = 205, alpha = 0.4, label = "50KeV", color='blue')
    ax1.hist(train_DS_s1ene_50,range = (rangemins1,rangemaxs1), density = True, bins = 205, alpha = 0.4, label = "50KeV", color='blue')
    ax1.hist(train_DS_s1ene_100,range = (rangemins1,rangemaxs1), density = True, bins = 205, alpha = 0.4, label = "100KeV", color='red')
    ax1.hist(train_DS_s1ene_150,range = (rangemins1,rangemaxs1), density = True, bins = 205, alpha = 0.4, label = "150KeV",color='green')

    ax1.hist(gen_data_50_s1,range = (rangemins1,rangemaxs1), density = True, bins = 205, color='blue')
    ax1.hist(gen_data_100_s1,range = (rangemins1,rangemaxs1), density = True, bins = 205, color='red')
    ax1.hist(gen_data_150_s1,range = (rangemins1,rangemaxs1), density = True, bins = 205, color='green')


    ax1.set_xlabel("s1 Energy")
    ax1.set_ylabel(r"$\rho\left(x\right)$", size=14, labelpad=30, rotation="horizontal")
    ax1.legend(loc="upper right", fontsize=10)
    #ax1.text(60,0.75*0.8,f"Epochs: {e}")
    #ax1.text(60,0.65*0.8,f"Batch Size: {batch_size}")

    ax2.hist(train_DS_s2ene_50,range = (rangemins2,rangemaxs2), density = True, bins = 205, alpha = 0.4, label = "50KeV", color='blue')
    ax2.hist(train_DS_s2ene_100,range = (rangemins2,rangemaxs2), density = True, bins = 205, alpha = 0.4, label = "100KeV", color='red')
    ax2.hist(train_DS_s2ene_150,range = (rangemins2,rangemaxs2), density = True, bins = 205, alpha = 0.4, label = "150KeV",color='green')


    ax2.hist(gen_data_50_s2,range = (rangemins2,rangemaxs2), density = True, bins = 205, color='blue')
    ax2.hist(gen_data_100_s2,range = (rangemins2,rangemaxs2), density = True, bins = 205, color='red')
    ax2.hist(gen_data_150_s2,range = (rangemins2,rangemaxs2), density = True, bins = 205, color='green')


    ax2.set_xlabel("s2 Energy")
    ax2.set_ylabel(r"$\rho\left(x\right)$", size=14, labelpad=30, rotation="horizontal")
    #ax2.title(f"s2 from a 2D cGAN at Epoch {e} and batch size {batch_size}")
    #ax2.text(8.5,0.75*5,f"Epochs: {e}")
    #ax2.text(8.5,0.65*5,f"Batch Size: {batch_size}")

    ax2.legend(loc="upper right", fontsize=10)

    plt.show()

# %%
mass = 200

hyperparams = np.full(fill_value=mass, shape=(100000, 1))
z = np.random.normal(size=(10000, noise_size))
datapoints = gc.predict([z, hyperparams])[:,0]
s1_true = plt.hist(train_DS_ene_200,range = (40,70), density = True, bins = 205, alpha = 1, color='red', label = 'G4 Data')
s1_gen = plt.hist(datapoints,range = (40,70), density = True, bins = 205, alpha = 0.4, color='red', label = 'Generated Data')


plt.legend(loc="upper right", fontsize=10)
plt.xlabel("s1 energy", size=14, labelpad=10)
plt.ylabel(r"$\rho\left(x\right)$", size=14, labelpad=30, rotation="horizontal")
plt.title("Comparing our CGAN with unseen G4 Data for 200KeV")

s1_diff = s1_true[0] - s1_gen[0]

sum_s1_diff = 0
for i in range(len(s1_diff)):
  sum_s1_diff += abs(s1_diff[i])

plt.text(60,0.43,f"Loss: {round(sum_s1_diff)}")

plt.show()

print(f"          MASS = {mass}")
print(f"GENERATED MEAN = {np.mean(datapoints):.1f}")

# %%
del epoch_no[0]
del real_loss[0]
del real_acc[0]
h3 = plt.plot(epoch_no,real_loss, color = 'blue', label = "Loss")
h4 = plt.plot(epoch_no,real_acc, color = 'orange', label = "Accuracy")
plt.xlabel("Epoch number", size=14, labelpad=10)
plt.ylabel("Loss", size=14, labelpad=30, rotation="vertical")
plt.title(f"Disciminator variables with batch size {batch_size} for s1 vs s2")
plt.legend(loc="upper right", fontsize=10)
plt.show()
